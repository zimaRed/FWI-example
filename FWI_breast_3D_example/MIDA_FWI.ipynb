# %%
# Set up Stride

import condacolab
condacolab.install()
# !git clone https://github.com/trustimaging/stride.git
# %cd stride
# !conda env create -f environment.yml
# !source activate stride
# !pip install -e .


# Set up Mosaic runtime for distributed computing

import mosaic

await mosaic.interactive('on', num_workers=4, log_level='info')

runtime = mosaic.runtime()
# Out:
# ✨🍰✨ Everything looks OK!
# fatal: destination path 'stride' already exists and is not an empty directory.
# /content/stride
#
# CondaValueError: prefix already exists: /usr/local/envs/stride
#
# Obtaining file:///content/stride
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: blosc in /usr/local/lib/python3.10/site-packages (from stride==1.2) (1.11.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.10/site-packages (from stride==1.2) (2.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/site-packages (from stride==1.2) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (3.1.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/site-packages (from stride==1.2) (3.0.11)
# Requirement already satisfied: dash>=2.0.0 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (2.18.2)
# Requirement already satisfied: devito in /usr/local/lib/python3.10/site-packages (from stride==1.2) (4.8.11)
# Requirement already satisfied: flake8 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (7.1.1)
# Requirement already satisfied: gputil in /usr/local/lib/python3.10/site-packages (from stride==1.2) (1.4.0)
# Requirement already satisfied: h5py>=3.2 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (3.12.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/site-packages (from stride==1.2) (0.70.17)
# Requirement already satisfied: nbval in /usr/local/lib/python3.10/site-packages (from stride==1.2) (0.11.0)
# Requirement already satisfied: ndsplines in /usr/local/lib/python3.10/site-packages (from stride==1.2) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (2.0.2)
# Requirement already satisfied: notebook>=6.4 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (7.2.2)
# Requirement already satisfied: pre_commit in /usr/local/lib/python3.10/site-packages (from stride==1.2) (4.0.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/site-packages (from stride==1.2) (6.1.0)
# Requirement already satisfied: pyflakes in /usr/local/lib/python3.10/site-packages (from stride==1.2) (3.2.0)
# Requirement already satisfied: py-libnuma in /usr/local/lib/python3.10/site-packages (from stride==1.2) (1.2)
# Requirement already satisfied: pytest in /usr/local/lib/python3.10/site-packages (from stride==1.2) (8.3.3)
# Requirement already satisfied: pytest-cov in /usr/local/lib/python3.10/site-packages (from stride==1.2) (6.0.0)
# Requirement already satisfied: pytest-runner in /usr/local/lib/python3.10/site-packages (from stride==1.2) (6.0.1)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (6.0.2)
# Requirement already satisfied: pyzmq>=22.1 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (26.2.0)
# Requirement already satisfied: python-daemon in /usr/local/lib/python3.10/site-packages (from stride==1.2) (3.1.0)
# Requirement already satisfied: resampy in /usr/local/lib/python3.10/site-packages (from stride==1.2) (0.4.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/site-packages (from stride==1.2) (0.24.0)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (1.14.1)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.10/site-packages (from stride==1.2) (8.1.3)
# Requirement already satisfied: sphinx_rtd_theme in /usr/local/lib/python3.10/site-packages (from stride==1.2) (3.0.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (6.4.2)
# Requirement already satisfied: tblib in /usr/local/lib/python3.10/site-packages (from stride==1.2) (3.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/site-packages (from stride==1.2) (2.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/site-packages (from stride==1.2) (4.66.1)
# Requirement already satisfied: ipympl in /usr/local/lib/python3.10/site-packages (from stride==1.2) (0.9.4)
# Requirement already satisfied: uvloop in /usr/local/lib/python3.10/site-packages (from stride==1.2) (0.21.0)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.10/site-packages (from stride==1.2) (3.0.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (5.24.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (5.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (4.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (2.31.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/site-packages (from dash>=2.0.0->stride==1.2) (68.2.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.10/site-packages (from notebook>=6.4->stride==1.2) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /usr/local/lib/python3.10/site-packages (from notebook>=6.4->stride==1.2) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /usr/local/lib/python3.10/site-packages (from notebook>=6.4->stride==1.2) (4.2.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/lib/python3.10/site-packages (from notebook>=6.4->stride==1.2) (0.2.4)
# Requirement already satisfied: pip>=9.0.1 in /usr/local/lib/python3.10/site-packages (from devito->stride==1.2) (23.3.2)
# Requirement already satisfied: py-cpuinfo<10 in /usr/local/lib/python3.10/site-packages (from devito->stride==1.2) (9.0.0)
# Requirement already satisfied: cgen>=2020.1 in /usr/local/lib/python3.10/site-packages (from devito->stride==1.2) (2020.1)
# Requirement already satisfied: codepy>=2019.1 in /usr/local/lib/python3.10/site-packages (from devito->stride==1.2) (2023.1)
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/site-packages (from devito->stride==1.2) (6.1.0)
# Requirement already satisfied: anytree<=2.12.1,>=2.4.3 in /usr/local/lib/python3.10/site-packages (from devito->stride==1.2) (2.12.1)
# Requirement already satisfied: sympy<1.14,>=1.12.1 in /usr/local/lib/python3.10/site-packages (from devito->stride==1.2) (1.13.1)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/site-packages (from flake8->stride==1.2) (0.7.0)
# Requirement already satisfied: pycodestyle<2.13.0,>=2.12.0 in /usr/local/lib/python3.10/site-packages (from flake8->stride==1.2) (2.12.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/site-packages (from ipympl->stride==1.2) (0.2.0)
# Requirement already satisfied: ipython<9 in /usr/local/lib/python3.10/site-packages (from ipympl->stride==1.2) (8.29.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.10/site-packages (from ipympl->stride==1.2) (8.1.5)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /usr/local/lib/python3.10/site-packages (from ipympl->stride==1.2) (3.9.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/site-packages (from ipympl->stride==1.2) (11.0.0)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.10/site-packages (from ipympl->stride==1.2) (5.14.3)
# Requirement already satisfied: dill>=0.3.9 in /usr/local/lib/python3.10/site-packages (from multiprocess->stride==1.2) (0.3.9)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/site-packages (from nbval->stride==1.2) (8.6.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/site-packages (from nbval->stride==1.2) (5.10.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/site-packages (from nbval->stride==1.2) (6.29.5)
# Requirement already satisfied: coverage in /usr/local/lib/python3.10/site-packages (from nbval->stride==1.2) (7.6.8)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.10/site-packages (from pytest->stride==1.2) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/site-packages (from pytest->stride==1.2) (23.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.10/site-packages (from pytest->stride==1.2) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.10/site-packages (from pytest->stride==1.2) (1.2.2)
# Requirement already satisfied: tomli>=1 in /usr/local/lib/python3.10/site-packages (from pytest->stride==1.2) (2.1.0)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.10/site-packages (from pre_commit->stride==1.2) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.10/site-packages (from pre_commit->stride==1.2) (2.6.2)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.10/site-packages (from pre_commit->stride==1.2) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.10/site-packages (from pre_commit->stride==1.2) (20.27.1)
# Requirement already satisfied: lockfile>=0.10 in /usr/local/lib/python3.10/site-packages (from python-daemon->stride==1.2) (0.12.2)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.10/site-packages (from resampy->stride==1.2) (0.60.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/site-packages (from scikit-image->stride==1.2) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/site-packages (from scikit-image->stride==1.2) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/site-packages (from scikit-image->stride==1.2) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/site-packages (from scikit-image->stride==1.2) (0.4)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (3.1.4)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (2.18.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/site-packages (from sphinx->stride==1.2) (1.4.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.10/site-packages (from sphinx_rtd_theme->stride==1.2) (4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (3.16.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/site-packages (from torch->stride==1.2) (3.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/site-packages (from sympy<1.14,>=1.12.1->devito->stride==1.2) (1.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/site-packages (from anytree<=2.12.1,>=2.4.3->devito->stride==1.2) (1.16.0)
# Requirement already satisfied: pytools>=2015.1.2 in /usr/local/lib/python3.10/site-packages (from cgen>=2020.1->devito->stride==1.2) (2024.1.16)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/site-packages (from codepy>=2019.1->devito->stride==1.2) (4.1.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->stride==1.2) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->stride==1.2) (1.9.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/site-packages (from ipython<9->ipympl->stride==1.2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/site-packages (from ipython<9->ipympl->stride==1.2) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/site-packages (from ipython<9->ipympl->stride==1.2) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/site-packages (from ipython<9->ipympl->stride==1.2) (3.0.48)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/site-packages (from ipython<9->ipympl->stride==1.2) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/site-packages (from ipython<9->ipympl->stride==1.2) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl->stride==1.2) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /usr/local/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl->stride==1.2) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl->stride==1.2) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from Jinja2>=3.1->sphinx->stride==1.2) (3.0.2)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (4.6.2.post1)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (23.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (7.16.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.21.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from jupyter-client->nbval->stride==1.2) (2.9.0.post0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.4->stride==1.2) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.4->stride==1.2) (0.27.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.10/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.4->stride==1.2) (2.2.5)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/site-packages (from ipykernel->nbval->stride==1.2) (1.8.9)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.4->stride==1.2) (0.9.28)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.4->stride==1.2) (4.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl->stride==1.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl->stride==1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl->stride==1.2) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl->stride==1.2) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl->stride==1.2) (3.2.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/site-packages (from nbformat->nbval->stride==1.2) (2.20.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/site-packages (from numba>=0.53->resampy->stride==1.2) (0.43.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/site-packages (from plotly>=5.0.0->dash>=2.0.0->stride==1.2) (9.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests->dash>=2.0.0->stride==1.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests->dash>=2.0.0->stride==1.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests->dash>=2.0.0->stride==1.2) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests->dash>=2.0.0->stride==1.2) (2023.11.17)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre_commit->stride==1.2) (0.3.9)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/site-packages (from importlib-metadata->dash>=2.0.0->stride==1.2) (3.21.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.4->stride==1.2) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.4->stride==1.2) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl->stride==1.2) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.4->stride==1.2) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.4->stride==1.2) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.4->stride==1.2) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.4->stride==1.2) (0.21.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl->stride==1.2) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl->stride==1.2) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl->stride==1.2) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl->stride==1.2) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl->stride==1.2) (0.2.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (0.5.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (2.4)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4->stride==1.2) (2.9.0.20241003)
# Installing collected packages: stride
#   Attempting uninstall: stride
#     Found existing installation: stride 1.2
#     Uninstalling stride-1.2:
#       Successfully uninstalled stride-1.2
#   Running setup.py develop for stride
# Successfully installed stride-1.2
# Listening at <CommsManager object at 132362366019920, uid=monitor, address=cda333da0c00, port=3000, state=connected>HEAD            Listening at <CommsManager object at 132362366018528, uid=head, address=cda333da0c00, port=3003, state=connected>
# MONITOR         Listening at <NODE:0 | WORKER:0-4>

# %%
from stride.utils import fetch, wavelets
from stride import Space, Time, Grid
from stride import Problem, ScalarField
import numpy as np
import h5py
import matplotlib.pyplot as plt
# %matplotlib widget

# Load the MIDA model
with h5py.File('/content/mida_model.h5', 'r') as f:
    vp_data = np.array(f['vp'])
    print(f"Model data shape: {vp_data.shape}")
    print(f"Data range: min={np.min(vp_data)}, max={np.max(vp_data)}")
    print(f"Data type: {vp_data.dtype}")

# Paper settings:
# - Sub-MHz frequencies (100-850 kHz)
# - 500μm isotropic resolution
# - 1024 transducers around the head
spacing = (0.5e-3, 0.5e-3, 0.5e-3)  # 500μm spacing as per paper
space = Space(shape=vp_data.shape,
             extra=(50, 50, 50),     # Extra space for wave propagation
             absorbing=(40, 40, 40),  # Absorbing boundary conditions
             spacing=spacing)

# Time settings based on paper's sub-MHz frequency requirements
dt = 0.08e-6  # Time step
T = 240e-6    # Total time (240 μs as per paper)
nt = int(T/dt)
time = Time(start=0, step=dt, num=nt)

grid = Grid(space, time)

# Create problem
problem = Problem(name='head3D', space=space, time=time)

# Create transducers - paper uses 1024 transducers
num_locations = 1024  # As specified in paper
problem.transducers.default()

# Set up geometry for transducer placement
# Paper places transducers around the head in 3D, avoiding face
radius = ((space.limit[0] - 30e-3) / 2,
         (space.limit[1] - 30e-3) / 2,
         (space.limit[2] - 30e-3) / 2)
centre = (space.limit[0] / 2,
         space.limit[1] / 2,
         space.limit[2] / 2)

# Create ellipsoidal arrangement avoiding the face area
problem.geometry.default('ellipsoidal', num_locations, radius, centre,
                       theta=np.pi * 0.75,  # Reduced angle to avoid face
                       threshold=0.5)

# Setup acquisitions
problem.acquisitions.default()

# Create wavelets - paper uses 100-850 kHz bandwidth
f_centre = 0.4e6  # 400 kHz center frequency
n_cycles = 3      # 3-cycle tone burst as mentioned in paper

for shot in problem.acquisitions.shots:
    shot.wavelets.data[0, :] = wavelets.tone_burst(f_centre, n_cycles, time.num, time.step)

# Load velocity model
vp_true = ScalarField(name='vp', grid=grid, data=vp_data)
problem.medium.add(vp_true)

# Enhanced visualization
plt.figure(figsize=(15, 5))

# Plot three orthogonal slices
plt.subplot(131)
plt.imshow(vp_data[vp_data.shape[0]//2, :, :], cmap='viridis')
plt.title('Sagittal View')
plt.colorbar(label='Velocity (m/s)')

plt.subplot(132)
plt.imshow(vp_data[:, vp_data.shape[1]//2, :], cmap='viridis')
plt.title('Coronal View')
plt.colorbar(label='Velocity (m/s)')

plt.subplot(133)
plt.imshow(vp_data[:, :, vp_data.shape[2]//2], cmap='viridis')
plt.title('Axial View')
plt.colorbar(label='Velocity (m/s)')

plt.tight_layout()
plt.show()

# Print configuration details
print("\nProblem configuration:")
print(f"Space shape: {space.shape}")
print(f"Spatial resolution: {spacing[0]*1e3} mm")
print(f"Number of transducers: {num_locations}")
print(f"Center frequency: {f_centre/1e6} MHz")
print(f"Time samples: {time.num}")
print(f"Total simulation time: {T*1e6} μs")

# Try problem visualization
try:
    problem.plot()
except Exception as e:
    print(f"\nError in problem visualization: {e}")
    print("Attempting alternative visualization...")
    try:
        fig = plt.figure(figsize=(10, 10))
        ax = fig.add_subplot(111, projection='3d')

        # Plot transducer positions
        positions = problem.geometry.coordinates
        ax.scatter(positions[:, 0], positions[:, 1], positions[:, 2],
                  c='red', marker='o', label='Transducers')

        # Add a semi-transparent volume to show head boundaries
        x, y, z = np.meshgrid(np.linspace(0, space.limit[0], 10),
                             np.linspace(0, space.limit[1], 10),
                             np.linspace(0, space.limit[2], 10))
        ax.scatter(x, y, z, alpha=0.1)

        ax.set_xlabel('X (m)')
        ax.set_ylabel('Y (m)')
        ax.set_zlabel('Z (m)')
        ax.legend()
        plt.show()
    except Exception as e:
        print(f"Alternative visualization failed: {e}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-039b1ab6a70e> in <cell line: 10>()
#       8
#       9 # Load the MIDA model
# ---> 10 with h5py.File('/Users/leozaroff/mida_model.h5', 'r') as f:
#      11     vp_data = np.array(f['vp'])
#      12     print(f"Model data shape: {vp_data.shape}")
#
# /usr/local/lib/python3.10/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     559                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                                  fs_page_size=fs_page_size)
# --> 561                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     562
#     563             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.10/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233         if swmr and swmr_support:
#     234             flags |= h5f.ACC_SWMR_READ
# --> 235         fid = h5f.open(name, flags, fapl=fapl)
#     236     elif mode == 'r+':
#     237         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/Users/leozaroff/mida_model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
import os
os.environ['DEVITO_PLATFORM'] = 'nvidiaX'
os.environ['DEVITO_LANGUAGE'] = 'openacc'

# %%
from stride import IsoAcousticDevito

# Set up PDE solver for wave propagation
pde = IsoAcousticDevito.remote(grid=problem.grid, len=runtime.num_workers)

# %%
from stride import forward

# Run default forward workflow
await forward(problem, pde, vp_true, dump=False)
# Out:
# ---------------------------------------------------------------------------
# MemoryOverflowError                       Traceback (most recent call last)
# Cell In[11], line 4
#       1 from stride import forward
#       3 # Run default forward workflow
# ----> 4 await forward(problem, pde, vp_true, dump=False)
#
# File ~/Desktop/Stride/stride/stride/__init__.py:165, in forward(problem, pde, *args, **kwargs)
#     162     if deallocate is True:
#     163         shot.observed.deallocate()
# --> 165 await loop
#
# File ~/Desktop/Stride/stride/mosaic/runtime/runtime.py:378, in Runtime.async_for.<locals>._async_for(func)
#     376 for task in asyncio.as_completed(tasks, timeout=timeout):
#     377     try:
# --> 378         res = await task
#     379         gather.append(res)
#     380     except RuntimeDisconnectedError as exc:
#
# File ~/miniconda3/envs/stride/lib/python3.11/asyncio/tasks.py:615, in as_completed.<locals>._wait_for_one()
#     612 if f is None:
#     613     # Dummy value from _on_timeout().
#     614     raise exceptions.TimeoutError
# --> 615 return f.result()
#
# File ~/Desktop/Stride/stride/mosaic/runtime/runtime.py:369, in Runtime.async_for.<locals>._async_for.<locals>.call(*iters)
#     366 res = None
#     368 async with self._exclusive_proxy(worker_queue, safe=safe) as _worker:
# --> 369     res = await func(_worker, *iters)
#     371 return res
#
# File ~/Desktop/Stride/stride/stride/__init__.py:144, in forward.<locals>.loop(worker, shot_id)
#     141         raise ValueError('Unknown platform %s' % platform)
#     143 # run PDE
# --> 144 traces = await pde(wavelets, *published_args,
#     145                    problem=sub_problem,
#     146                    runtime=worker, **_kwargs).result()
#     148 logger.perf('Shot %d retrieved' % sub_problem.shot_id)
#     150 # save data
#
# File ~/Desktop/Stride/stride/mosaic/core/task.py:802, in TaskProxy.result(self)
#     793 async def result(self):
#     794     """
#     795     Gather remote result from the task.
#     796
#    (...)
#     800
#     801     """
# --> 802     await self
#     804     if hasattr(self, '_retrieved'):
#     805         return self._retrieved
#
# File ~/Desktop/Stride/stride/mosaic/core/task.py:872, in TaskProxy.__await__(self)
#     871 def __await__(self):
# --> 872     yield from self._done_future.__await__()
#     873     return self
#
# File ~/Desktop/Stride/stride/mosaic/utils/event_loop.py:83, in Future.__await__(self)
#      82 def __await__(self):
# ---> 83     return (yield from self._future.__await__())
#
# File ~/Desktop/Stride/stride/mosaic/core/task.py:449, in _check_ready()
#     447 if self.runtime._running_tasks <= 0:
#     448     try:
# --> 449         raise MemoryOverflowError('Not enough memory to allocate %d bytes '
#     450                                   'for task %s' % (self._arg_size, self))
#     451     except MemoryOverflowError:
#     452         et, ev, tb = sys.exc_info()
#
# MemoryOverflowError: Not enough memory to allocate 843659745 bytes for task <Task object at 4951990096, uid=task-isoacousticdevito-__call__-d75ad273c71c4644baaa561127db703a, runtime=worker:0:0, state=pending>

# %% [markdown]
# Starting model:
#
# Unlike in the forward problem, the speed of sound field is unknown to us at this point. We need to choose a starting assumption to begin optimizing from. Here we assume a homogenous speed of 1500 m/s (~water's speed of sound).

# %%
# Initialize starting model for inversion
vp = ScalarField.parameter(name='vp', grid=grid, needs_grad=True)
vp.fill(1500.) # Initialize with a constant velocity

problem.medium.add(vp)

# %% [markdown]
# Imaging operators:
#
# Define operators for our loss function, processing our source wavelets and the modelled/observed data traces, and an optimizer to update the speed of sound model after each iteration (here we use gradient descent).
#
# We also limited the speed of sound to between 1400 and 1700 m/s, which will need to change when we introduce bone.

# %%
from stride import L2DistanceLoss

# Set up optimization components
loss = L2DistanceLoss.remote(len=runtime.num_workers)

from stride import ProcessWavelets, ProcessObserved, ProcessWaveletsObserved, ProcessTraces


process_wavelets = ProcessWavelets.remote(len=runtime.num_workers)
process_observed = ProcessObserved.remote(len=runtime.num_workers)
process_wavelets_observed = ProcessWaveletsObserved.remote(len=runtime.num_workers)
process_traces = ProcessTraces.remote(len=runtime.num_workers)

from stride import GradientDescent, ProcessGlobalGradient, ProcessModelIteration

# Configure optimization parameters
step_size = 10
process_grad = ProcessGlobalGradient()
process_model = ProcessModelIteration(min=1400., max=1700.)

optimiser = GradientDescent(vp, step_size=step_size,
                            process_grad=process_grad,
                            process_model=process_model)

# %% [markdown]
# Inverse problem -- estimating the speed of sound:
#
# We use a multi-frequency approach, starting with lower frequencies and then moving to higher frequencies for more detail. This is done by dividing the optimization into blocks, each with a max frequency.
#
# During each iteration, only a random subset of the shots will actually be used.
#
# Here we use the utility function "adjoint" to run this optimization loop. If you want to see more detailed code, take a look at the 2d example notebook.

# %%
from stride import OptimisationLoop

# Clear the previous Devito operators
await pde.clear_operators()

optimisation_loop = OptimisationLoop()

# Specify a series of frequency bands, which we will introduce gradually
# into the inversion in order to better condition it
# Run multi-frequency inversion

max_freqs = [0.3e6, 0.4e6]

num_blocks = len(max_freqs)
num_iters = 4

for block, freq in optimisation_loop.blocks(num_blocks, max_freqs):
    await adjoint(problem, pde, loss,
        optimisation_loop, optimiser, vp,
        num_iters=num_iters,
        select_shots=dict(num=15, randomly=True),
        f_max=freq)

vp.plot()

# %% [markdown]
# Tear down the mosaic runtime:

# %%
await mosaic.interactive('off')
